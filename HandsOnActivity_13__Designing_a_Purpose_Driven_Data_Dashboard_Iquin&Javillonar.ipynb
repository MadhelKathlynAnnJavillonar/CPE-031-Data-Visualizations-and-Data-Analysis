# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhelKathlynAnnJavillonar/CPE-031-Data-Visualizations-and-Data-Analysis/blob/main/HandsOnActivity_13__Designing_a_Purpose_Driven_Data_Dashboard_Iquin%26Javillonar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 13 | Designing a Purpose-Driven Data Dashboard**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Iquin, Melquisedec & Javillonar, Madhel Kathlyn Ann
# Course Code and Title : CPE 031/CPE21S2
# Date Submitted : 11/9/2025
# Instructor : Engr. Maria Rizette Sayo
#
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to demonstrate students’ ability to design purposeful and user-centered data dashboards. Students will analyze the dashboard’s purpose, evaluate user requirements, and apply engineering principles such as clarity, accuracy, and interactivity in creating effective visual designs.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze how a dashboard’s purpose affects its overall design.
#
# 2. Evaluate how well a dashboard meets the needs of its users.
#
# 3. Create an interactive dashboard that applies clarity, accuracy, and usability.

# %% [markdown]
# **3. Discussions:**
#
# A well-designed data dashboard is more than a collection of charts — it’s a purposeful storytelling tool that connects data to decisions.
#
# Understanding the Purpose of the Data Dashboard:
# Every dashboard must have a clear objective — whether it’s to monitor performance, analyze patterns, or inform strategic decisions. The design should align with this goal, focusing only on the most relevant data and metrics.
#
# Considering the Needs of the Data Dashboard’s Users:
# Dashboards should be designed with the user in mind. A manager may need high-level KPIs, while an analyst may need granular, filterable data. Knowing the user’s goals, skills, and workflow ensures that the dashboard supports, rather than overwhelms, their decision-making.
#
# Data Dashboard Engineering:
# Engineering a dashboard involves organizing visual elements efficiently, ensuring smooth interactivity, and maintaining data accuracy. It also includes performance considerations (like handling large datasets), responsive design, and consistent color schemes.

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Step 1: Install and Import Required Libraries

# %%
# !pip install plotly pandas
import pandas as pd
import numpy as np
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Step 2: Create a Sample Dataset
#
# We’ll simulate student performance data to design an academic performance dashboard.

# %%
# Create dataset
np.random.seed(10)
students = [f"Student {i}" for i in range(1, 21)]
subjects = ["Math", "Science", "English", "Programming", "Data Analytics"]

data = {
    "Student": np.random.choice(students, 100),
    "Subject": np.random.choice(subjects, 100),
    "Score": np.random.randint(60, 100, 100),
    "Attendance (%)": np.random.randint(70, 100, 100)
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Student         Subject  Score  Attendance (%)
# 0  Student 10         English     76              99
# 1   Student 5  Data Analytics     71              98
# 2  Student 16         English     99              75
# 3   Student 1         Science     77              85
# 4  Student 18         Science     99              90

# %% [markdown]
# Step 3: Design Dashboard Components

# %%
# Average Score per Subject
fig1 = px.bar(df.groupby("Subject", as_index=False)["Score"].mean(),
              x="Subject", y="Score", title="Average Score per Subject",
              color="Score", color_continuous_scale="Blues")

# Attendance vs. Score Scatter
fig2 = px.scatter(df, x="Attendance (%)", y="Score", color="Subject",
                  title="Attendance vs. Performance", hover_data=["Student"])

# Score Distribution
fig3 = px.box(df, x="Subject", y="Score", title="Score Distribution by Subject",
              color="Subject")

fig1.show()
fig2.show()
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ed1603e-b545-4daf-b57f-77b0a428119a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ed1603e-b545-4daf-b57f-77b0a428119a")) {                    Plotly.newPlot(                        "0ed1603e-b545-4daf-b57f-77b0a428119a",                        [{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Data Analytics","English","Math","Programming","Science"],"xaxis":"x","y":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f930b42-8b0e-4204-9e0c-112281a5d630" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f930b42-8b0e-4204-9e0c-112281a5d630")) {                    Plotly.newPlot(                        "7f930b42-8b0e-4204-9e0c-112281a5d630",                        [{"customdata":[["Student 10"],["Student 16"],["Student 20"],["Student 12"],["Student 12"],["Student 19"],["Student 3"],["Student 16"],["Student 16"],["Student 12"],["Student 16"],["Student 13"],["Student 14"],["Student 2"],["Student 19"],["Student 1"],["Student 15"],["Student 19"],["Student 18"]],"hovertemplate":"Subject=English\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"English","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"English","orientation":"v","showlegend":true,"x":[99,75,87,71,72,94,88,79,96,98,92,84,85,85,73,82,84,80,80],"xaxis":"x","y":[76,99,91,89,65,79,92,62,77,89,67,89,62,72,70,76,84,86,79],"yaxis":"y","type":"scatter"},{"customdata":[["Student 5"],["Student 17"],["Student 11"],["Student 9"],["Student 11"],["Student 18"],["Student 15"],["Student 6"],["Student 5"],["Student 8"],["Student 13"],["Student 13"],["Student 1"],["Student 9"],["Student 19"],["Student 16"],["Student 20"],["Student 18"],["Student 17"],["Student 1"],["Student 10"]],"hovertemplate":"Subject=Data Analytics\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Data Analytics","orientation":"v","showlegend":true,"x":[98,91,83,90,86,76,71,95,85,92,70,77,93,75,88,90,87,76,93,96,93],"xaxis":"x","y":[71,93,65,73,96,63,91,99,80,91,60,88,79,92,98,98,87,60,87,85,93],"yaxis":"y","type":"scatter"},{"customdata":[["Student 1"],["Student 18"],["Student 10"],["Student 15"],["Student 14"],["Student 14"],["Student 16"],["Student 19"],["Student 17"],["Student 8"],["Student 12"],["Student 12"],["Student 13"],["Student 9"],["Student 14"],["Student 7"],["Student 10"],["Student 17"],["Student 15"],["Student 17"]],"hovertemplate":"Subject=Science\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Science","orientation":"v","showlegend":true,"x":[85,90,84,84,75,87,93,91,87,96,72,78,89,94,96,80,95,91,99,81],"xaxis":"x","y":[77,99,75,76,82,95,90,81,92,77,73,92,75,85,90,66,65,67,69,72],"yaxis":"y","type":"scatter"},{"customdata":[["Student 18"],["Student 9"],["Student 1"],["Student 5"],["Student 9"],["Student 14"],["Student 20"],["Student 13"],["Student 14"],["Student 12"],["Student 2"],["Student 19"],["Student 18"],["Student 9"],["Student 11"],["Student 12"],["Student 14"],["Student 17"],["Student 20"],["Student 11"],["Student 10"]],"hovertemplate":"Subject=Math\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Math","orientation":"v","showlegend":true,"x":[90,73,84,90,82,87,93,93,85,85,99,73,74,73,90,75,84,88,94,71,71],"xaxis":"x","y":[71,74,81,63,65,81,69,95,77,70,98,85,60,83,76,94,75,71,92,86,71],"yaxis":"y","type":"scatter"},{"customdata":[["Student 17"],["Student 5"],["Student 16"],["Student 2"],["Student 5"],["Student 18"],["Student 20"],["Student 6"],["Student 2"],["Student 5"],["Student 10"],["Student 8"],["Student 1"],["Student 11"],["Stude ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7977a0a1-97d6-4860-9608-029fe2a3b18a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7977a0a1-97d6-4860-9608-029fe2a3b18a")) {                    Plotly.newPlot(                        "7977a0a1-97d6-4860-9608-029fe2a3b18a",                        [{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"English","marker":{"color":"#636efa"},"name":"English","notched":false,"offsetgroup":"English","orientation":"v","showlegend":true,"x":["English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English"],"x0":" ","xaxis":"x","y":[76,99,91,89,65,79,92,62,77,89,67,89,62,72,70,76,84,86,79],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics","marker":{"color":"#EF553B"},"name":"Data Analytics","notched":false,"offsetgroup":"Data Analytics","orientation":"v","showlegend":true,"x":["Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics"],"x0":" ","xaxis":"x","y":[71,93,65,73,96,63,91,99,80,91,60,88,79,92,98,98,87,60,87,85,93],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science","marker":{"color":"#00cc96"},"name":"Science","notched":false,"offsetgroup":"Science","orientation":"v","showlegend":true,"x":["Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science"],"x0":" ","xaxis":"x","y":[77,99,75,76,82,95,90,81,92,77,73,92,75,85,90,66,65,67,69,72],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#ab63fa"},"name":"Math","notched":false,"offsetgroup":"Math","orientation":"v","showlegend":true,"x":["Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math"],"x0":" ","xaxis":"x","y":[71,74,81,63,65,81,69,95,77,70,98,85,60,83,76,94,75,71,92,86,71],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Programming","marker":{"color":"#FFA15A"},"name":"Programming","notched":false,"offsetgroup":"Programming","orientation":"v","showlegend":true,"x":["Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming"],"x0":" ","xaxis":"x","y":[72,83,77,80,66,70,64,79,71,78,60,92,97,82,67,87,65,79,83],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...

# %% [markdown]
# Step 4: Combine into One Interactive Dashboard

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Aggregated data
avg_scores = df.groupby("Subject", as_index=False)["Score"].mean()
avg_attendance = df.groupby("Subject", as_index=False)["Attendance (%)"].mean()

# Dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Average Score per Subject", "Attendance vs. Score",
                                    "Score Distribution", "Average Attendance per Subject"),
                    specs=[[{"type": "bar"}, {"type": "scatter"}],
                           [{"type": "box"}, {"type": "bar"}]])

fig.add_trace(go.Bar(x=avg_scores["Subject"], y=avg_scores["Score"], name="Average Score"), row=1, col=1)
fig.add_trace(go.Scatter(x=df["Attendance (%)"], y=df["Score"], mode="markers", name="Scatter Plot"), row=1, col=2)
fig.add_trace(go.Box(x=df["Subject"], y=df["Score"], name="Score Distribution"), row=2, col=1)
fig.add_trace(go.Bar(x=avg_attendance["Subject"], y=avg_attendance["Attendance (%)"], name="Average Attendance"), row=2, col=2)

fig.update_layout(height=700, width=950, title_text="🎓 Student Performance Dashboard")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c526a0d7-7cbf-4b68-b5fd-edf878b56730" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c526a0d7-7cbf-4b68-b5fd-edf878b56730")) {                    Plotly.newPlot(                        "c526a0d7-7cbf-4b68-b5fd-edf878b56730",                        [{"name":"Average Score","x":["Data Analytics","English","Math","Programming","Science"],"y":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"type":"bar","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Scatter Plot","x":[99,98,75,85,90,91,90,73,84,84,83,90,90,87,71,72,71,71,72,82,82,88,84,83,72,75,94,87,93,87,93,71,80,94,85,85,86,76,93,91,87,96,72,76,71,75,78,99,86,89,95,85,92,73,70,88,94,79,96,96,80,78,98,70,77,93,74,92,84,73,90,85,75,85,73,84,75,95,84,82,72,89,88,88,91,84,94,90,87,76,80,99,93,71,98,96,80,93,81,71],"y":[76,71,99,77,99,93,71,74,75,81,65,73,63,91,72,83,77,89,65,80,65,66,76,70,64,82,79,81,69,95,95,71,78,79,77,70,96,60,90,81,92,77,73,63,91,92,92,98,97,75,99,80,91,85,60,92,85,62,90,77,66,82,89,67,88,79,60,67,89,83,76,62,94,72,70,75,92,65,87,76,65,79,71,98,67,84,92,98,87,60,86,69,87,86,83,85,79,93,72,71],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"name":"Score Distribution","x":["English","Data Analytics","English","Science","Science","Data Analytics","Math","Math","Science","Math","Data Analytics","Data Analytics","Math","English","Programming","Programming","Programming","English","English","Programming","Math","Programming","Science","Programming","Programming","Science","Programming","Math","Math","Science","Math","Programming","Programming","English","Math","Math","Data Analytics","Programming","Science","Science","Science","Science","Science","Data Analytics","Data Analytics","Programming","Science","Math","Programming","Science","Data Analytics","Data Analytics","Data Analytics","Math","Data Analytics","English","Science","English","Science","English","Science","Programming","English","Programming","Data Analytics","Data Analytics","Math","English","English","Math","Math","English","Math","English","English","Math","Data Analytics","Science","Programming","English","Programming","Programming","Math","Data Analytics","Science","English","Math","Data Analytics","Data Analytics","Data Analytics","English","Science","Data Analytics","Math","Programming","Data Analytics","English","Data Analytics","Science","Math"],"y":[76,71,99,77,99,93,71,74,75,81,65,73,63,91,72,83,77,89,65,80,65,66,76,70,64,82,79,81,69,95,95,71,78,79,77,70,96,60,90,81,92,77,73,63,91,92,92,98,97,75,99,80,91,85,60,92,85,62,90,77,66,82,89,67,88,79,60,67,89,83,76,62,94,72,70,75,92,65,87,76,65,79,71,98,67,84,92,98,87,60,86,69,87,86,83,85,79,93,72,71],"type":"box","xaxis":"x3","yaxis":"y3"},{"name":"Average Attendance","x":["Data Analytics","English","Math","Programming","Science"],"y":[85.95238095238095,84.42105263157895,83.52380952380952,79.57894736842105,87.35],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %% [markdown]
# **Task 1:** Define the Purpose
#
# Write a short paragraph (3–5 sentences) describing the purpose of your dashboard.

# %% [markdown]
# The purpose of this dashboard is to visualize and analyze student performance data in various subjects. It helps users easily track scores, attendance, and identify trends or patterns in student progress. By combining visual insights from bar, scatter, and box plots, the dashboard allows teachers and students to make data-driven decisions to improve academic outcomes.

# %% [markdown]
# **Task 2:** Design for User Needs
#
# Modify the dashboard to meet specific user needs:
#
# If your user is a teacher, highlight underperforming students.
#
# If your user is a student, highlight their personal progress vs. class average.
#
# If your user is a department head, summarize subject-level averages only.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

np.random.seed(10)
students = [f"Student {i}" for i in range(1, 21)]
subjects = ["Math", "Science", "English", "Programming", "Data Analytics"]

data = {
    "Student": np.random.choice(students, 100),
    "Subject": np.random.choice(subjects, 100),
    "Score": np.random.randint(60, 100, 100),
    "Attendance (%)": np.random.randint(70, 100, 100)
}

df = pd.DataFrame(data)

class_avg = df["Score"].mean()

df["Performance"] = np.where(df["Score"] < class_avg, "Underperforming", "Satisfactory")

fig = px.scatter(df, x="Attendance (%)", y="Score",
                 color="Performance", title="Student Performance (Highlighting Underperformers)",
                 color_discrete_map={"Underperforming": "red", "Satisfactory": "green"},
                 hover_data=["Student", "Subject"])

fig.add_hline(y=class_avg, line_dash="dash", line_color="blue",
              annotation_text="Class Average", annotation_position="bottom right")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b2f1dba2-a85f-4f2e-b70b-31bf5d556138" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2f1dba2-a85f-4f2e-b70b-31bf5d556138")) {                    Plotly.newPlot(                        "b2f1dba2-a85f-4f2e-b70b-31bf5d556138",                        [{"customdata":[["Student 10","English"],["Student 5","Data Analytics"],["Student 1","Science"],["Student 18","Math"],["Student 9","Math"],["Student 10","Science"],["Student 11","Data Analytics"],["Student 9","Data Analytics"],["Student 5","Math"],["Student 17","Programming"],["Student 16","Programming"],["Student 12","English"],["Student 9","Math"],["Student 5","Programming"],["Student 15","Science"],["Student 18","Programming"],["Student 20","Programming"],["Student 6","Programming"],["Student 20","Math"],["Student 2","Programming"],["Student 5","Programming"],["Student 19","English"],["Student 14","Math"],["Student 12","Math"],["Student 10","Programming"],["Student 8","Science"],["Student 12","Science"],["Student 18","Data Analytics"],["Student 13","Science"],["Student 13","Data Analytics"],["Student 16","English"],["Student 16","English"],["Student 7","Science"],["Student 17","Programming"],["Student 1","Data Analytics"],["Student 18","Math"],["Student 16","English"],["Student 11","Math"],["Student 14","English"],["Student 2","English"],["Student 19","English"],["Student 14","Math"],["Student 10","Science"],["Student 1","English"],["Student 19","Programming"],["Student 4","Programming"],["Student 17","Math"],["Student 17","Science"],["Student 18","Data Analytics"],["Student 15","Science"],["Student 18","English"],["Student 17","Science"],["Student 10","Math"]],"hovertemplate":"Performance=Underperforming\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cbr\u003eSubject=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Underperforming","marker":{"color":"red","symbol":"circle"},"mode":"markers","name":"Underperforming","orientation":"v","showlegend":true,"x":[99,98,85,90,73,84,83,90,90,71,71,72,82,88,84,83,72,94,93,71,80,94,85,85,76,96,72,76,89,70,79,96,80,70,93,74,92,90,85,85,73,84,95,82,72,89,88,91,76,99,80,81,71],"xaxis":"x","y":[76,71,77,71,74,75,65,73,63,72,77,65,65,66,76,70,64,79,69,71,78,79,77,70,60,77,73,63,75,60,62,77,66,67,79,60,67,76,62,72,70,75,65,76,65,79,71,67,60,69,79,72,71],"yaxis":"y","type":"scatter"},{"customdata":[["Student 16","English"],["Student 18","Science"],["Student 17","Data Analytics"],["Student 1","Math"],["Student 20","English"],["Student 5","Programming"],["Student 12","English"],["Student 2","Programming"],["Student 14","Science"],["Student 14","Math"],["Student 14","Science"],["Student 13","Math"],["Student 11","Data Analytics"],["Student 16","Science"],["Student 19","Science"],["Student 17","Science"],["Student 15","Data Analytics"],["Student 8","Programming"],["Student 12","Science"],["Student 2","Math"],["Student 1","Programming"],["Student 6","Data Analytics"],["Student 5","Data Analytics"],["Student 8","Data Analytics"],["Student 19","Math"],["Student 3","English"],["Student 9","Science"],["Student 14","Science"],["Student 11","Programming"],["Student 12","English"],["Student 13","Data Analytics"],["Student 13","English"],["Student 9","Math"],["Student 12","Math"],["Student 9","Data Analytics"],["Student 6","Programming"],["Student 19","Data Analytics"],["Student 15","English"],["Student 20","Math"],["Student 16","Data Analytics"],["Student 20","Data Analytics"],["Student 19","English"],["Student 17","Data Analytics"],["Student 11","Math"],["Student 18","Programming"],["Student 1","Data Analytics"],["Student 10","Data Analytics"]],"hovertemplate":"Performance=Sa ...

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# Design Your Own Dashboard: “Smart Campus Energy Monitor”
# Create a dashboard that shows the energy usage of different campus areas (e.g., laboratories, offices, classrooms) over time.
#
# 1. Simulate or use sample data (Energy consumption per hour or per day).
#
# 2. Include at least three charts (bar, line, pie).
#
# 3. Ensure your design reflects a clear purpose and target user (e.g., facilities manager).
#
# 4. Write a short explanation of your engineering decisions (why you chose certain colors, layouts, or interactivity).
#
# **Smart Campus Energy Monitor** dashboard is designed for a facilities manager to easily track and compare energy usage across different areas of the campus.
#
# I ued three visual types — a bar chart for comparing average usage, a line chart for showing changes over time, and a pie chart for seeing overall energy share.
# The color palette (soft blues, greens, and oranges) was chosen for clarity and readability.
# The layout and chart titles were made simple and direct to help users interpret data quickly without distractions.
# This design focuses on clarity, accessibility, and purpose, allowing the manager to identify which areas consume the most energy and take action to improve efficiency.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Simulated energy consumption data
np.random.seed(42)
areas = ["Laboratory", "Office", "Classroom"]
days = pd.date_range("2025-01-01", periods=7)

data = {
    "Date": np.tile(days, 3),
    "Area": np.repeat(areas, 7),
    "Energy (kWh)": np.random.randint(50, 200, 21)
}

df = pd.DataFrame(data)

# Bar Chart: Average energy consumption per area
bar_chart = px.bar(df.groupby("Area", as_index=False)["Energy (kWh)"].mean(),
                   x="Area", y="Energy (kWh)", color="Area",
                   title="Average Energy Usage per Campus Area",
                   color_discrete_sequence=px.colors.qualitative.Set2)

# Line Chart: Daily energy trend
line_chart = px.line(df, x="Date", y="Energy (kWh)", color="Area",
                     title="Daily Energy Consumption Trend")

# Pie Chart: Total energy share by area
pie_chart = px.pie(df, values="Energy (kWh)", names="Area",
                   title="Energy Usage Distribution by Area",
                   color_discrete_sequence=px.colors.qualitative.Pastel)

# Show charts
bar_chart.show()
line_chart.show()
pie_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6e53ccb-2ee8-4ba4-a29c-b8683f70e37e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6e53ccb-2ee8-4ba4-a29c-b8683f70e37e")) {                    Plotly.newPlot(                        "d6e53ccb-2ee8-4ba4-a29c-b8683f70e37e",                        [{"alignmentgroup":"True","hovertemplate":"Area=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Classroom","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"Classroom","offsetgroup":"Classroom","orientation":"v","showlegend":true,"textposition":"auto","x":["Classroom"],"xaxis":"x","y":[117.85714285714286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Laboratory","marker":{"color":"rgb(252,141,98)","pattern":{"shape":""}},"name":"Laboratory","offsetgroup":"Laboratory","orientation":"v","showlegend":true,"textposition":"auto","x":["Laboratory"],"xaxis":"x","y":[122.42857142857143],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office","marker":{"color":"rgb(141,160,203)","pattern":{"shape":""}},"name":"Office","offsetgroup":"Office","orientation":"v","showlegend":true,"textposition":"auto","x":["Office"],"xaxis":"x","y":[154.28571428571428],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="89f05676-c54d-4062-95fe-a48e551bd8a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f05676-c54d-4062-95fe-a48e551bd8a1")) {                    Plotly.newPlot(                        "89f05676-c54d-4062-95fe-a48e551bd8a1",                        [{"hovertemplate":"Area=Laboratory\u003cbr\u003eDate=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Laboratory","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Laboratory","orientation":"v","showlegend":true,"x":["2025-01-01T00:00:00","2025-01-02T00:00:00","2025-01-03T00:00:00","2025-01-04T00:00:00","2025-01-05T00:00:00","2025-01-06T00:00:00","2025-01-07T00:00:00"],"xaxis":"x","y":[152,142,64,156,121,70,152],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=Office\u003cbr\u003eDate=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Office","orientation":"v","showlegend":true,"x":["2025-01-01T00:00:00","2025-01-02T00:00:00","2025-01-03T00:00:00","2025-01-04T00:00:00","2025-01-05T00:00:00","2025-01-06T00:00:00","2025-01-07T00:00:00"],"xaxis":"x","y":[171,124,137,166,149,153,180],"yaxis":"y","type":"scatter"},{"hovertemplate":"Area=Classroom\u003cbr\u003eDate=%{x}\u003cbr\u003eEnergy (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Classroom","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Classroom","orientation":"v","showlegend":true,"x":["2025-01-01T00:00:00","2025-01-02T00:00:00","2025-01-03T00:00:00","2025-01-04T00:00:00","2025-01-05T00:00:00","2025-01-06T00:00:00","2025-01-07T00:00:00"],"xaxis":"x","y":[199,102,51,137,87,179,70],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="158ffdf5-17b4-4cee-9e6f-c5e9234ba5bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("158ffdf5-17b4-4cee-9e6f-c5e9234ba5bf")) {                    Plotly.newPlot(                        "158ffdf5-17b4-4cee-9e6f-c5e9234ba5bf",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Area=%{label}\u003cbr\u003eEnergy (kWh)=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Laboratory","Laboratory","Laboratory","Laboratory","Laboratory","Laboratory","Laboratory","Office","Office","Office","Office","Office","Office","Office","Classroom","Classroom","Classroom","Classroom","Classroom","Classroom","Classroom"],"legendgroup":"","name":"","showlegend":true,"values":[152,142,64,156,121,70,152,171,124,137,166,149,153,180,199,102,51,137,87,179,70],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6 ...

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# In this activity, I learned how to design and interpret dashboards that turn raw data into clear, meaningful insights. By applying user-centered design, I understood how visual choices like color, chart type, and layout affect how information is understood. Creating the “Smart Campus Energy Monitor” helped me practice using data visualization tools to analyze energy usage and present it effectively for decision-making. Overall, this activity improved my analytical skills and showed me how engineering and data visualization work together to solve real-world problems.
